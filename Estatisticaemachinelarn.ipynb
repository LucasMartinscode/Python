# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasMartinscode/LucasMartinscode/blob/main/Estatisticaemachinelarn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
echo "# machinelearneestatistica" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/LucasMartinscode/machinelearneestatistica.git
git push -u origin main

#Objetivo
#Descobrir a previsão de renda da pessoa se será menor ou maior que é 50 mil dolares utilizando machine learn 

import pandas as pd #Abrindo pandas para tratar base de dados
import random 
import numpy as np #Biblioteca para tratar funções de computação númerica

dataset = pd.read_csv('census.csv')

dataset.head() #Imprimi as 5 primeiras linhas da base de dados
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %%
dataset.tail() # Imprimindo as 5 ultimas informações da base de dados
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %% [markdown]
# Amostragem Aleatória simples

# %%
Amostra_aleatoria_simples = dataset.sample( n= 100, random_state = 1) # Amostra simples utilizando 100 linhas e com o comando random_state consigo sempre utilizar as mesmas amostras, caso alterar o número, serão outras

Amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
Amostra_aleatoria_simples.head() #Ids diferentes da base de dados
# Out:
#        age     workclass  final-weight      education  education-num  \
# 16054   42     State-gov        160369        HS-grad              9
# 32382   44     Local-gov        150171        HS-grad              9
# 10749   39     Local-gov        256997      Bachelors             13
# 15377   39       Private        147548        HS-grad              9
# 29660   29   Federal-gov        106179   Some-college             10
#
#             marital-status        occupation    relationship    race      sex  \
# 16054        Never-married   Protective-serv   Not-in-family   White     Male
# 32382             Divorced      Adm-clerical       Unmarried   White   Female
# 10749   Married-civ-spouse      Craft-repair         Husband   White     Male
# 15377   Married-civ-spouse      Craft-repair         Husband   White     Male
# 29660        Never-married    Prof-specialty   Not-in-family   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# ...
